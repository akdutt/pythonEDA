# %%
#Step 1. Import the necessary libraries¶ 
import numpy as np
import pandas as pd
import collections
import matplotlib.pyplot as plt
import seaborn as sbn
# %matplotlib inline

# %%
#Step 2. Import the dataset from this address.¶

url='https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv'

#Step 3. Assign it to a variable called tips¶

tips=pd.read_csv(url)

# %%
#Step 4. Delete the Unnamed 0 column¶
T=tips.drop('Unnamed: 0',axis=1).head()

# %%
#Step 5. Plot the total_bill column histogram¶
sbn.distplot(tips['total_bill'])

# %%
#Step 6. Create a scatter plot presenting the relationship between total_bill and tip
sbn.jointplot(data = tips , x = 'total_bill' , y = 'tip' ,color = 'blue' ,kind = 'scatter')

# %%
#Step 7. Create one image with the relationship of total_bill, tip and size.
sbn.pairplot(tips)

# %%
#Step 8. Present the relationship between days and total_bill value¶
sbn.stripplot(data = tips , x = 'day' , y = 'total_bill')

# %%
#Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex¶
sbn.stripplot(data = tips , x = 'tip' , y = 'day',hue = "sex")

# %%
#Step 10. Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)¶

sbn.boxplot(data = tips,x = "day", y = "total_bill", hue = "time");
# Out:
# /usr/local/lib/python2.7/dist-packages/seaborn/categorical.py:482: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data[hue_mask])
